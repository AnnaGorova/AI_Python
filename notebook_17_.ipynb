# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.animation as animation 

from sklearn.cluster import KMeans 

from sklearn.datasets import make_blobs

# %%
X, y_true = make_blobs(
    n_samples=500,
    centers=4,
    cluster_std=1.0,
    random_state=42
)

df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df.head()
# Out:
#    Feature 1  Feature 2
# 0  -7.689054   6.620346
# 1  -9.576514  -6.934404
# 2   6.829682   1.164871
# 3  -2.901306   7.550771
# 4  -5.678413  -7.288185

# %%
plt.figure(figsize=(7, 5))
plt.scatter(df["Feature 1"], df["Feature 2"], s=35, 
    alpha=0.8)

plt.title("Initial Data Points")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
df["cluster_kmeans"] = kmeans.labels_

# %%
fig, ax = plt.subplots(figsize=(7, 5))


colors = ["red", "blue", "green", "orange"]

for cluster in range(4):
    subset = df[df["cluster_kmeans"] == cluster]
    ax.scatter(
        subset["Feature 1"],
        subset["Feature 2"],
        color=colors[cluster],
        label=f"Cluster {cluster}",
        s=60,
        alpha=0.5,
        edgecolors="black",   
        linewidth=0.5    
    )

centers = kmeans.cluster_centers_
ax.scatter(
    centers[:, 0],
    centers[:, 1],
    c="black",
    marker="X",
    s=200,
    label="Centers"

)

ax.set_title("K-Means Clustering (4 clusters)")
ax.set_xlabel("Feature 1")
ax.set_ylabel("Feature 2")
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.8, min_samples=5)

# %%
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.8)

# %%
df["cluster_dbscan"] = dbscan.labels_

# %%
fig, ax = plt.subplots(figsize=(7, 5))

unique_labels = set(dbscan.labels_)
colors = ["red", "blue", "green", "orange", "purple", "brown", "pink", "gray"]

for i, label in enumerate(unique_labels):
    if label == -1:
        color = "black"
        marker = "x"
        label_name = "Noise"
    else:
        color = colors[i % len(colors)]
        marker = "o"
        label_name = f"Cluster {label}"
    
    subset = df[df["cluster_dbscan"] == label]
    ax.scatter(
        subset["Feature 1"],
        subset["Feature 2"],
        color=color,
        marker=marker,
        label=label_name,
        s=35,
        alpha=0.8,
        edgecolors="black" if label != -1 else None,
        linewidth=0.3
    )

ax.set_title("DBSCAN Clustering")
ax.set_xlabel("Feature 1")
ax.set_ylabel("Feature 2")
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
noise_count = (df["cluster_dbscan"] == -1).sum()
print(f"мітка -1: {noise_count}")
print(f"Кількість кластерів: {len(set(dbscan.labels_)) - (1 if -1 in set(dbscan.labels_) else 0)}")
print(f"Розподіл по кластерах:\n{df['cluster_dbscan'].value_counts().sort_index()}")
# Out:
# мітка -1: 16
# Кількість кластерів: 4
# Розподіл по кластерах:
# cluster_dbscan
# -1     16
#  0    124
#  1    120
#  2    119
#  3    121
# Name: count, dtype: int64
